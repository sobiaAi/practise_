# %%
#taylor series approximation of sin(x)
# I learned truncation error, convergence, catastrophic cancellation, extrapolation failure
# to experiment with this code, change n (which is no. of terms) and the range of x rn its -2pi to 2pi you can make it -pi to pi!
# x is range
# the list taylors_values holds individual values of each range value
# n is number of terms in the expansion
# total is the final sum of the taylors expansion for the individual k value
# term is singular taylor term
# k=0,1,2,3,4 etc

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# import sympy as sp
# x=sp.symbols("x")
x=np.linspace(2*(-np.pi), 2*(np.pi), 100)
taylor_values=[]
n=5
for j in range(len(x)):
    total=0
    for k in range(n):
        term= (((-1)**k)*((x[j])**((2*k)+1)))/factorial((2*k)+1)
        total+=term
    taylor_values.append(total)

# %%
fig, ax = plt.subplots()
ax.plot(x, taylor_values, label=f'taylor n={n}')
ax.plot(x, np.sin(x), label='true sin')

ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.legend()
plt.show()
